# %%
import os
import databricks.koalas as ks

diapole_moments = ks.read_csv(os.path.join("..","data","dipole_moments.csv"))

# %%
diapole_moments = ks.read_csv(os.path.join("..","data","dipole_moments.csv"))
magnetic_sheilding_tensors = ks.read_csv(os.path.join("..","data","magnetic_shielding_tensors.csv"))
mulliken_charges = ks.read_csv(os.path.join("..","data","mulliken_charges.csv"))
potential_energy = ks.read_csv(os.path.join("..","data","potential_energy.csv"))
scalar_coupling_contributions = ks.read_csv(os.path.join("..","data","scalar_coupling_contributions.csv"))
structures = ks.read_csv(os.path.join("..","data","structures.csv"))

# %% [markdown]
# <code>
# magnetic_sheilding_tensors_mulliken_charges_df = pd.merge(
#     left=magnetic_sheilding_tensors,
#     right=mulliken_charges,
#     how="left",
#     on=None,
#     left_on=['molecule_name','atom_index'],
#     right_on=['molecule_name','atom_index'],
#     left_index=False,
#     right_index=False,
#     sort=True,
#     suffixes=("_x", "_y"),
#     copy=True,
#     indicator=False,
#     validate=None,
# )
# </code>

# %%
# %%time
magnetic_sheilding_tensors.head()
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 78.4 ms
#       molecule_name  atom_index        XX      YX      ZX      XY        YY      ZY      XZ      YZ        ZZ
# 0  dsgdb9nsd_000001           0  195.3147  0.0000 -0.0001  0.0000  195.3171  0.0007 -0.0001  0.0007  195.3169
# 1  dsgdb9nsd_000001           1   31.3410 -1.2317  4.0544 -1.2317   28.9546 -1.7173  4.0546 -1.7173   34.0861
# 2  dsgdb9nsd_000001           2   31.5814  1.2173 -4.1474  1.2173   28.9036 -1.6036 -4.1476 -1.6036   33.8967
# 3  dsgdb9nsd_000001           3   31.5172  4.1086  1.2723  4.1088   33.9068  1.6950  1.2724  1.6951   28.9579
# 4  dsgdb9nsd_000001           4   31.4029 -4.0942 -1.1793 -4.0944   34.0776  1.6259 -1.1795  1.6260   28.9013

# %%
ks.merge(
    magnetic_sheilding_tensors, 
    mulliken_charges, 
    left_on=['molecule_name','atom_index'], 
    right_on=['molecule_name','atom_index']
)
# Out:
#         molecule_name  atom_index        XX        YX        ZX        XY        YY        ZY        XZ        YZ        ZZ  mulliken_charge
# 0    dsgdb9nsd_000021           7   27.2778   -0.0024    0.0013   -0.0026   27.2698   -0.0026    0.0003    0.0003   34.9161         0.071533
# 1    dsgdb9nsd_000066           9   27.0237    1.4117   -1.9754    1.2775   30.2412    4.4634   -2.8054    3.8220   38.9207         0.284148
# 2    dsgdb9nsd_000121           2  185.3185   -1.2196   -0.0132   -8.3453  167.7450    0.0040   -0.0168    0.0106  150.6279        -0.329533
# 3    dsgdb9nsd_000158           7   30.0203    0.4285   -3.3560    0.9941   25.3139   -0.1663   -3.6993    1.8617   25.4098         0.103907
# 4    dsgdb9nsd_000194           1   12.9773   22.8650    0.9180   25.7693   52.8245    1.1249   -2.7735    8.9736  115.9965         0.266409
# ...

# %%
magnetic_sheilding_tensors_mulliken_charges_df = pd.merge(
    left=magnetic_sheilding_tensors,
    right=mulliken_charges,
    how="left",
    on=None,
    left_on=['molecule_name','atom_index'],
    right_on=['molecule_name','atom_index'],
    left_index=False,
    right_index=False,
    sort=True,
    suffixes=("_x", "_y"),
    copy=True,
    indicator=False,
    validate=None,
)
