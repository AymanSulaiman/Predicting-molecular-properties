# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# len(os.listdir('../data/structures'))

# %%
# train = pd.read_csv('../data/train.csv')
# train

# %%
# len(list(set(train.molecule_name.to_list())))

# %%
# test = pd.read_csv('../data/test.csv')
# test

# %%
# len(list(set(test.molecule_name.to_list())))

# %%
diapole_moments = pd.read_csv(os.path.join("..","data","dipole_moments.csv"))
magnetic_sheilding_tensors = pd.read_csv(os.path.join("..","data","magnetic_shielding_tensors.csv"))
mulliken_charges = pd.read_csv(os.path.join("..","data","mulliken_charges.csv"))
potential_energy = pd.read_csv(os.path.join("..","data","potential_energy.csv"))
scalar_coupling_contributions = pd.read_csv(os.path.join("..","data","scalar_coupling_contributions.csv"))
structures = pd.read_csv(os.path.join("..","data","structures.csv"))

# %%
diapole_moments
# Out:
#            molecule_name       X       Y       Z
# 0       dsgdb9nsd_000001  0.0000  0.0000  0.0000
# 1       dsgdb9nsd_000002 -0.0002  0.0000  1.6256
# 2       dsgdb9nsd_000003  0.0000  0.0000 -1.8511
# 3       dsgdb9nsd_000004  0.0000  0.0000  0.0000
# 4       dsgdb9nsd_000005  0.0000  0.0000 -2.8937
# ...                  ...     ...     ...     ...
# 130784  dsgdb9nsd_133881  1.2590  0.1153 -1.0814
# 130785  dsgdb9nsd_133882 -0.3710 -1.2435  0.0000
# 130786  dsgdb9nsd_133883 -0.4359  1.1694 -0.0000
# 130787  dsgdb9nsd_133884  1.3623  1.4058 -0.0000
# 130788  dsgdb9nsd_133885 -0.8578 -0.0909 -0.0000
#
# [130789 rows x 4 columns]

# %%
magnetic_sheilding_tensors
# Out:
#             molecule_name  atom_index        XX      YX      ZX      XY  \
# 0        dsgdb9nsd_000001           0  195.3147  0.0000 -0.0001  0.0000
# 1        dsgdb9nsd_000001           1   31.3410 -1.2317  4.0544 -1.2317
# 2        dsgdb9nsd_000001           2   31.5814  1.2173 -4.1474  1.2173
# 3        dsgdb9nsd_000001           3   31.5172  4.1086  1.2723  4.1088
# 4        dsgdb9nsd_000001           4   31.4029 -4.0942 -1.1793 -4.0944
# ...                   ...         ...       ...     ...     ...     ...
# 2358870  dsgdb9nsd_133885          11   28.6323 -0.1148 -2.2990  1.9651
# 2358871  dsgdb9nsd_133885          12   31.2449  6.1929  6.3054  3.8977
# 2358872  dsgdb9nsd_133885          13   33.8789 -3.6278  0.0001  0.6389
# 2358873  dsgdb9nsd_133885          14   28.6324 -0.1148  2.2990  1.9652
# 2358874  dsgdb9nsd_133885          15   31.2450  6.1927 -6.3056  3.8978
#
#                YY      ZY      XZ      YZ        ZZ
# ...

# %%
mulliken_charges
# Out:
#             molecule_name  atom_index  mulliken_charge
# 0        dsgdb9nsd_000001           0        -0.535689
# 1        dsgdb9nsd_000001           1         0.133921
# 2        dsgdb9nsd_000001           2         0.133922
# 3        dsgdb9nsd_000001           3         0.133923
# 4        dsgdb9nsd_000001           4         0.133923
# ...                   ...         ...              ...
# 2358870  dsgdb9nsd_133885          11         0.078144
# 2358871  dsgdb9nsd_133885          12         0.099332
# 2358872  dsgdb9nsd_133885          13         0.114018
# 2358873  dsgdb9nsd_133885          14         0.078144
# 2358874  dsgdb9nsd_133885          15         0.099332
#
# [2358875 rows x 3 columns]

# %%
potential_energy
# Out:
#            molecule_name  potential_energy
# 0       dsgdb9nsd_000001        -40.523680
# 1       dsgdb9nsd_000002        -56.560246
# 2       dsgdb9nsd_000003        -76.426077
# 3       dsgdb9nsd_000004        -77.335268
# 4       dsgdb9nsd_000005        -93.428488
# ...                  ...               ...
# 130784  dsgdb9nsd_133881       -400.761274
# 130785  dsgdb9nsd_133882       -400.757209
# 130786  dsgdb9nsd_133883       -380.894376
# 130787  dsgdb9nsd_133884       -364.872596
# 130788  dsgdb9nsd_133885       -400.760914
#
# [130789 rows x 2 columns]

# %%
scalar_coupling_contributions
# Out:
#             molecule_name  atom_index_0  atom_index_1  type          fc  \
# 0        dsgdb9nsd_000001             1             0  1JHC   83.022400
# 1        dsgdb9nsd_000001             1             2  2JHH  -11.034700
# 2        dsgdb9nsd_000001             1             3  2JHH  -11.032500
# 3        dsgdb9nsd_000001             1             4  2JHH  -11.031900
# 4        dsgdb9nsd_000001             2             0  1JHC   83.022200
# ...                   ...           ...           ...   ...         ...
# 4659071  dsgdb9nsd_133884            17             4  2JHC    3.586440
# 4659072  dsgdb9nsd_133884            17             5  3JHC    0.674583
# 4659073  dsgdb9nsd_133884            17             6  3JHC    1.337470
# 4659074  dsgdb9nsd_133884            17             7  2JHC    4.800620
# 4659075  dsgdb9nsd_133884            17             8  1JHC  115.975000
#
#                sd       pso       dso
# 0        0.254579  1.258620  0.272010
# ...

# %%
structures
# Out:
#             molecule_name  atom_index atom         x         y         z
# 0        dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1        dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2        dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3        dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4        dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
# ...                   ...         ...  ...       ...       ...       ...
# 2358870  dsgdb9nsd_133885          11    H -1.454004 -0.967309  1.459246
# 2358871  dsgdb9nsd_133885          12    H  0.277779 -2.697872  0.195770
# 2358872  dsgdb9nsd_133885          13    H  2.515854 -1.151784  0.527369
# 2358873  dsgdb9nsd_133885          14    H  0.013699  1.199431 -1.680192
# 2358874  dsgdb9nsd_133885          15    H  1.260745 -1.246754 -1.906767
#
# [2358875 rows x 6 columns]

# %%
# magnetic_sheilding_tensors_mulliken_charges_df = pd.merge(
#     left=magnetic_sheilding_tensors,
#     right=mulliken_charges,
#     how="left",
#     on=None,
#     left_on=['molecule_name','atom_index'],
#     right_on=['molecule_name','atom_index'],
#     left_index=False,
#     right_index=False,
#     sort=True,
#     suffixes=("_x", "_y"),
#     copy=True,
#     indicator=False,
#     validate=None,
# )
# magnetic_sheilding_tensors_mulliken_charges_df.to_csv(os.path.join('..','data','joined_data','magnetic_sheilding_tensors_mulliken_charges_df.csv'), index=False)

# %%
# magnetic_sheilding_tensors_mulliken_charges_df.head(2)

# %%
# diapole_moments_potential_energy_df = pd.merge(
#     left=diapole_moments,
#     right=potential_energy,
#     how="inner",
#     on=None,
#     left_on='molecule_name',
#     right_on='molecule_name',
#     left_index=False,
#     right_index=False,
#     sort=True,
#     suffixes=("_x", "_y"),
#     copy=True,
#     indicator=False,
#     validate=None,
# )
# diapole_moments_potential_energy_df.to_csv(os.path.join('..','data','joined_data','diapole_moments_potential_energy_df.csv'), index=False)

# %%
structures
# Out:
#             molecule_name  atom_index atom         x         y         z
# 0        dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1        dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2        dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3        dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4        dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
# ...                   ...         ...  ...       ...       ...       ...
# 2358870  dsgdb9nsd_133885          11    H -1.454004 -0.967309  1.459246
# 2358871  dsgdb9nsd_133885          12    H  0.277779 -2.697872  0.195770
# 2358872  dsgdb9nsd_133885          13    H  2.515854 -1.151784  0.527369
# 2358873  dsgdb9nsd_133885          14    H  0.013699  1.199431 -1.680192
# 2358874  dsgdb9nsd_133885          15    H  1.260745 -1.246754 -1.906767
#
# [2358875 rows x 6 columns]

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_df = pd.merge(
#     left=magnetic_sheilding_tensors_mulliken_charges_df,
#     right=structures,
#     how="left",
#     on=None,
#     left_on=['molecule_name','atom_index'],
#     right_on=['molecule_name','atom_index'],
#     left_index=False,
#     right_index=False,
#     sort=True,
#     suffixes=("_x", "_y"),
#     copy=True,
#     indicator=False,
#     validate=None,
# )
# magnetic_sheilding_tensors_mulliken_charges_structures_df.to_csv(os.path.join('..','data','joined_data','magnetic_sheilding_tensors_mulliken_charges_structures_df.csv'), index=False)

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_df

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df = pd.merge(
#     left=magnetic_sheilding_tensors_mulliken_charges_structures_df,
#     right=diapole_moments_potential_energy_df,
#     how="left",
#     on=None,
#     left_on=['molecule_name'],
#     right_on=['molecule_name'],
#     left_index=False,
#     right_index=False,
#     sort=True,
#     suffixes=("_x", "_y"),
#     copy=True,
#     indicator=False,
#     validate=None,
# )
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df.to_csv(os.path.join('..','data','joined_data','magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df.csv'), index=False)

# %%
magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-26d0976a72a0> in <module>
# ----> 1 magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df
#
# NameError: name 'magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df' is not defined

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df = magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df.drop('atom_index', axis=1)
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df

# %%
scalar_coupling_contributions

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_scalar_coupling_contributions_df = pd.merge(
#     left=magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_df,
#     right=scalar_coupling_contributions,
#     how="left",
#     on=None,
#     left_on=['molecule_name'],
#     right_on=['molecule_name'],
#     left_index=False,
#     right_index=False,
#     sort=True,
#     suffixes=("_x", "_y"),
#     copy=True,
#     indicator=False,
#     validate=None,
# )

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_scalar_coupling_contributions_df

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_scalar_coupling_contributions_df.to_csv(os.path.join('..','data','joined_data','magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_scalar_coupling_contributions_df.csv'), index=False)

# %%
# magnetic_sheilding_tensors_mulliken_charges_structures_diapole_moments_potential_energy_scalar_coupling_contributions_df.notnull

# %%
# !explorer .
